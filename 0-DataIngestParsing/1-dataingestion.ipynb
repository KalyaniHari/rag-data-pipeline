# %%
import os
from typing import List, Dict, Any
import pandas as pd

# %%
from langchain_core.documents import Document
from langchain_text_splitters import (
    CharacterTextSplitter,
    RecursiveCharacterTextSplitter,
    TokenTextSplitter,
)

# %%
doc=Document(page_content="This is a sample document. It contains multiple sentences. The purpose is to demonstrate text.",
                metadata={"source": "sample.txt",
                          "author": "Kalyani",
                          "date": "2025-01-21"})
print(f"content: {doc.page_content}")
print(f"Metadata: {doc.metadata}")
# Out:
# content: This is a sample document. It contains multiple sentences. The purpose is to demonstrate text.
# Metadata: {'source': 'sample.txt', 'author': 'Kalyani', 'date': '2025-01-21'}
